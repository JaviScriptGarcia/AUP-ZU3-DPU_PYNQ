# %%
  import pynq
  print("PYNQ version:", pynq.__version__)
  print("Bitfile:", pynq.PL.bitfile_name)

  from pynq.overlays.base import BaseOverlay
  overlay = BaseOverlay("base.bit")
  print("Base overlay IPs:")
  for ip in overlay.ip_dict.keys():
      print(" -", ip)
# Out:
# PYNQ version: 3.1
# Bitfile: None
# Base overlay IPs:
#  - mipi/demosaic
#  - mipi/gamma_lut
#  - mipi/gpio_ip_reset
#  - mipi/pixel_pack
#  - mipi/v_proc_sys
#  - axi_intc_0
#  - pl_rgb1_led
#  - pl_rgb2_led
#  - pl_rgb3_led
#  - pl_user_led
#  - audio/i2s_receiver_0
#  - shutdown_LPD
#  - system_management_wiz_0
#  - audio/i2s_transmitter_0
#  - audio/axi_gpio_0
#  - audio/axi_iic_aic
#  - SEL_JOYSTICK
#  - pl_user_pb
#  - pl_user_sw
#  - pl_rgb0_led
#  - mipi/axi_iic_0
#  - mipi/axi_vdma
#  - mipi/mipi_csi2_rx_subsyst
#  - shutdown_HP0_FPD
#  - zynq_ultra_ps_e_0
